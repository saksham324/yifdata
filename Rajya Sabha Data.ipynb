# %%
import pandas as pd 
import numpy as np

# %%
raj_data = pd.read_excel('Rajya.xls')
col = ['End of term']
raj_new = raj_data.ix[~(raj_data['End of term'] != 'In office') & (raj_data['Political party'] == 'Bhartiya Janata Party')]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
raj_new
# Out:
# Empty DataFrame
# Columns: [MP name, State, Political party, Gender, Age]
# Index: []

# %%
raj_new.columns
raj_new.
# Out:
# Index(['MP name', 'State', 'Political party', 'Gender', 'Age'], dtype='object')

# %%
raj_new.sort_values(['State'])
# Out:
#                          MP name              State  \
# 198  Kanakamedala Ravindra Kumar     Andhra Pradesh
# 540               Y. S. Chowdary     Andhra Pradesh
# 329      Prabhu Suresh Prabhakar     Andhra Pradesh
# 488              T. G. Venkatesh     Andhra Pradesh
# 266               Mohd. Ali Khan     Andhra Pradesh
# 491           T. Subbarami Reddy     Andhra Pradesh
# 327    Prabhakar Reddy Vemireddy     Andhra Pradesh
# 505     Thota Lakshmi Seetharama     Andhra Pradesh
# 96                   C.M. Ramesh     Andhra Pradesh
# 511           V. Vijayasai Reddy     Andhra Pradesh
# 177               K. Keshava Rao     Andhra Pradesh
# 273                  Mukut Mithi  Arunachal Pradesh
# 80            Bhubaneswar Kalita              Assam
# 391                  Ranee Narah              Assam
# 248               Manmohan Singh              Assam
# 90              Biswajit Daimary              Assam
# 403                   Ripun Bora              Assam
# ...

# %%
raj_new.to_excel('State.xlsx', index=False)
