# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn import metrics
import seaborn as sns

# %%
data_2009 = pd.read_csv('LS2009Candidate.csv')
data_2009
# Out:
#      ST_CODE      State name  Month  Year  PC Number      PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 5        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 6        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 7        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 8        S01  Andhra Pradesh      3  2009          1     Adilabad      ST
# 9        S01  Andhra Pradesh      3  2009          2   Peddapalle      SC
# 10       S01  Andhra Pradesh      3  2009          2   Peddapalle      SC
# 11       S01  Andhra Pradesh      3  2009          2   Peddapalle      SC
# ...

# %%
data_young = data_young[data_2009['Candidate Age'] < 30]
data_all = data_2009['Candidate Age']
data_all =
# Out:
# 35      True
# 119     True
# 127     True
# 133     True
# 138     True
# 142     True
# 154     True
# 156     True
# 170     True
# 178     True
# 180     True
# 181     True
# 187     True
# 188     True
# 192     True
# 194     True
# 277     True
# 285     True
# 300     True
# 310     True
# 385     True
# 400     True
# 415     True
# 447     True
# 457     True
# 459     True
# 467     True
# 494     True
# 502     True
# 566     True
#         ...
# 7584    True
# 7592    True
# 7607    True
# 7632    True
# 7633    True
# 7639    True
# 7642    True
# 7662    True
# 7669    True
# 7670    True
# 7697    True
# 7715    True
# 7724    True
# 7738    True
# 7743    True
# 7764    True
# 7801    True
# 7832    True
# 7875    True
# 7896    True
# 7902    True
# 7925    True
# 7927    True
# 7959    True
# 7964    True
# 7973    True
# 7976    True
# 8038    True
# 8059    True
# 8060    True
# Name: Candidate Age, Length: 564, dtype: bool

# %%
data1 = data_2009[['PC Number','PC name','PC Type', 'Candidate Sex', 'Candidate Category', 'Candidate Age', 'Total Votes Polled', 'Position' ]]

# %%
data2 = data1[['PC name', 'PC Type', 'Candidate Age', 'Total Votes Polled']]
data3 = data1[['PC name', 'Total Votes Polled']]
x = data3.groupby(['PC name']).sum()
x
# Out:
#                            Total Votes Polled
# PC name
# Adilabad                             863581.0
# Agra                                 647090.0
# Ahmadnagar                           786980.0
# Ahmedabad East                       597387.0
# Ahmedabad West                       690073.0
# Ajmer                                771160.0
# Akbarpur                             637254.0
# Akola                                738955.0
# Alappuzha                            907977.0
# Alathur                              828576.0
# Aligarh                              692055.0
# Alipurduars                          933734.0
# Allahabad                            550197.0
# Almora                               480757.0
# Alwar                                762694.0
# Amalapuram                          1023765.0
# Ambala                               866622.0
# Ambedkar Nagar                       810810.0
# Amethi                               646650.0
# ...

# %%
sns.set(style="darkgrid")
g = sns.jointplot("Candidate Age", "Total Votes Polled", data=data3, kind="reg", color="m")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-c2c7094d531a> in <module>()
#       1 sns.set(style="darkgrid")
# ----> 2 g = sns.jointplot("Candidate Age", "Total Votes Polled", data=data3, kind="reg", color="m")
#
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2239     grid = JointGrid(x, y, data, dropna=dropna,
#    2240                      size=size, ratio=ratio, space=space,
# -> 2241                      xlim=xlim, ylim=ylim)
#    2242
#    2243     # Plot the data using the grid
#
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1681             if isinstance(var, string_types):
# ...

# %%
data1
data2 = data1[['Candidate Age', 'Total Votes Polled']]
data2[['Candidate Age']] = data2[['Candidate Age']]- (data2[['Candidate Age']]%10)
plot = data2.groupby(['Candidate Age']).sum()
plot2 = data2.groupby(['Candidate Age']).size()
print(plot)
print(plot2)
# Out:
#                Total Votes Polled
# Candidate Age
# 20.0                    5749368.0
# 30.0                   52605729.0
# 40.0                  108508813.0
# 50.0                  138913416.0
# 60.0                   82664180.0
# 70.0                   24315013.0
# 80.0                    2310150.0
# 90.0                        955.0
# Candidate Age
# 20.0     564
# 30.0    2229
# 40.0    2296
# 50.0    1740
# 60.0     945
# 70.0     235
# 80.0      17
# 90.0       1
# dtype: int64
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
k_range = range(0,7)
total =0
for k in k_range:
    total = total + plot2.iloc[k]

# %%
plot2 = plot2/total
plot2 = plot2*100
print(plot2)
# Out:
# Candidate Age
# 20.0     7.027162
# 30.0    27.772240
# 40.0    28.607027
# 50.0    21.679541
# 60.0    11.774234
# 70.0     2.927984
# 80.0     0.211812
# 90.0     0.012460
# dtype: float64

# %%
x_range = range(0,7)
total2 = 0
for x in x_range:
    total2 = total2+ plot.iloc[x]
print(total2)
# Out:
# PC Number                156888.0
# Total Votes Polled    415066669.0
# Position                  75822.0
# dtype: float64

# %%
plot = plot/total2
plot = plot*100 
print(plot)
# Out:
#                PC Number  Total Votes Polled   Position
# Candidate Age
# 20.0            6.938708            1.385167   8.613595
# 30.0           27.782240           12.674043  32.272955
# 40.0           29.275024           26.142502  28.810899
# 50.0           21.670873           33.467736  18.426050
# 60.0           11.366707           19.915880   9.458996
# 70.0            2.742084            5.858098   2.260558
# 80.0            0.224364            0.556573   0.156947
# 90.0            0.001275            0.000230   0.019783

# %%
plot
# Out:
#                Total Votes Polled
# Candidate Age
# 20.0                    5749368.0
# 30.0                   52605729.0
# 40.0                  108508813.0
# 50.0                  138913416.0
# 60.0                   82664180.0
# 70.0                   24315013.0
# 80.0                    2310150.0
# 90.0                        955.0
